# %% [markdown]
# # 상품군 : 잡화

# %%
import pandas as pd 
import numpy as np 
import os 

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

# %%
from timeseries_graph_functions import *  # 시각화용 함수 만든것 불러오기

# %%
pd.set_option('display.float_format', '{:.2f}'.format)    #과학적 표기법 안쓸래 
mpl.rcParams['axes.unicode_minus'] = False               # 마이너스 표기 오류 방지

# %%
# 한글 폰트 깨짐 방지 
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()   
rc('font', family=font_name)
# plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
base_dir = "C:\\programming\\bigcontest_2020\\champion_league\\preprocess\\saejin"
excel_file = "원데이터 전처리.xlsx"

excel_dir = os.path.join(base_dir,excel_file)

# %%
raw_data = pd.read_excel(excel_dir, 
                             sheet_name = "Sheet1",
                             header = 0)

# %%
raw_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드             상품명  \
# 0               1 2019-01-01 06:00:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 1               2 2019-01-01 06:00:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 2               3 2019-01-01 06:20:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 3               4 2019-01-01 06:20:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 4               5 2019-01-01 06:40:00  20.00  100346  201072   테이트 남성 셀린니트3종
# ...           ...                 ...    ...     ...     ...             ...
# 35370       38296 2019-12-31 23:20:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
# 35371       38297 2019-12-31 23:40:00  20.00  100448  201383  무이자쿠첸압력밥솥 10인용
# 35372       38298 2019-12-31 23:40:00  20.00  100448  201390  일시불쿠첸압력밥솥 10인용
# 35373       38299 2019-12-31 23:40:00  20.00  100448  201384   무이자쿠첸압력밥솥 6인용
# 35374       38300 2019-12-31 23:40:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가       취급액        날짜  ...   월   일   요일  분기 365일  계절  방송시간  \
# 0      의류   39900   2099000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 1      의류   39900   4371000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 2      의류   39900   3262000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 3      의류   39900   6955000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 4      의류   39900   6672000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# ...    ..     ...       ...       ...  ...  ..  ..  ...  ..  ...  ..   ...
# 35370  주방  148000   1664000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35371  주방  178000   9149000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35372  주방  168000  15282000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35373  주방  158000   2328000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35374  주방  148000  10157000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
#
#        매진여부  취급액boxcox  최소판매수량
# 0         0     109.82      53
# 1         0     130.05     110
# 2         0     121.58      82
# 3         0     144.68     174
# 4         0     143.31     167
# ...     ...        ...     ...
# 35370     0     104.07      11
# 35371     0     154.06      51
# 35372     0     173.20      91
# 35373     0     112.48      15
# 35374     0     157.78      69
#
# [35375 rows x 21 columns]

# %% [markdown]
# # 상품군 : 잡화

# %%
general_merchandise_raw = raw_data[raw_data['상품군'] == '잡화']

# %%
focus_data = general_merchandise_raw

# %%
focus_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3694 entries, 165 to 35300
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3694 non-null   int64
#  1   방송일시        3694 non-null   datetime64[ns]
#  2   노출(분)       3694 non-null   float64
#  3   마더코드        3694 non-null   int64
#  4   상품코드        3694 non-null   int64
#  5   상품명         3694 non-null   object
#  6   상품군         3694 non-null   object
#  7   판매단가        3694 non-null   int64
#  8   취급액         3694 non-null   int64
#  9   날짜          3694 non-null   int64
#  10  시간          3694 non-null   object
#  11  월           3694 non-null   int64
#  12  일           3694 non-null   int64
#  13  요일          3694 non-null   object
#  14  분기          3694 non-null   object
#  15  365일        3694 non-null   int64
#  16  계절          3694 non-null   object
#  17  방송시간        3694 non-null   float64
#  18  매진여부        3694 non-null   int64
#  19  취급액boxcox   3694 non-null   float64
#  20  최소판매수량      3694 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(11), object(6)
# memory usage: 634.9+ KB

# %%
focus_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드  \
# 165           172 2019-01-03 06:00:00  20.00  100781  202292
# 166           173 2019-01-03 06:00:00  20.00  100781  202285
# 167           174 2019-01-03 06:20:00  20.00  100781  202292
# 168           175 2019-01-03 06:20:00  20.00  100781  202285
# 169           176 2019-01-03 06:40:00  20.00  100781  202292
# ...           ...                 ...    ...     ...     ...
# 35296       38218 2019-12-31 08:20:00  20.00  100390  201264
# 35297       38219 2019-12-31 08:40:00  20.00  100390  201261
# 35298       38220 2019-12-31 08:40:00  20.00  100390  201264
# 35299       38221 2019-12-31 09:00:00  20.00  100390  201261
# 35300       38222 2019-12-31 09:00:00  20.00  100390  201264
#
#                                  상품명 상품군   판매단가       취급액        날짜  ...   월  \
# 165                      에펨 여성 미들퍼부츠  잡화  39800   2450000  20190103  ...   1
# 166                      에펨 남성 미들퍼부츠  잡화  49800   2645000  20190103  ...   1
# 167                      에펨 여성 미들퍼부츠  잡화  39800   5609000  20190103  ...   1
# 168                      에펨 남성 미들퍼부츠  잡화  49800   3874000  20190103  ...   1
# 169                      에펨 여성 미들퍼부츠  잡화  39800   9045000  20190103  ...   1
# ...                              ...  ..    ...       ...       ...  ...  ..
# 35296  [RYN] 린 여성 다이얼락 히트 웜 퍼 방한화 2종  잡화  49000   6997000  20191231  ...  12
# 35297  [RYN] 린 남성 다이얼락 히트 웜 퍼 방한화 2종  잡화  49000  12394000  20191231  ...  12
# 35298  [RYN] 린 여성 다이얼락 히트 웜 퍼 방한화 2종  잡화  49000  13563000  20191231  ...  12
# 35299  [RYN] 린 남성 다이얼락 히트 웜 퍼 방한화 2종  잡화  49000  21728000  20191231  ...  12
# 35300  [RYN] 린 여성 다이얼락 히트 웜 퍼 방한화 2종  잡화  49000  20858000  20191231  ...  12
#
#         일   요일  분기 365일  계절  방송시간  매진여부  취급액boxcox  최소판매수량
# 165     3  목요일  Q1    3  겨울 20.00     0     113.81      62
# 166     3  목요일  Q1    3  겨울 20.00     0     115.84      53
# 167     3  목요일  Q1    3  겨울 20.00     0     137.72     141
# 168     3  목요일  Q1    3  겨울 20.00     0     126.49      78
# 169     3  목요일  Q1    3  겨울 20.00     0     153.65     227
# ...    ..  ...  ..  ...  ..   ...   ...        ...     ...
# 35296  31  화요일  Q4  365  겨울 20.00     0     144.88     143
# 35297  31  화요일  Q4  365  겨울 20.00     0     165.12     253
# 35298  31  화요일  Q4  365  겨울 20.00     0     168.55     277
# 35299  31  화요일  Q4  365  겨울 20.00     0     187.66     443
# 35300  31  화요일  Q4  365  겨울 20.00     0     185.92     426
#
# [3694 rows x 21 columns]

# %%
sales_by_month(focus_data)

# %%
sales_by_time(focus_data)

# %%
sales_by_yoill(focus_data)

# %%
sales_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 총합')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 평균')

# %%
soldout_by_season(focus_data)
# Out:
#     매진여부
# 계절
# 가을     0
# 겨울     0
# 봄      0
# 여름     5

# %%
unitprice_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 총액')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 평균')

# %%
quantity_by_season(focus_data)

# %%
sales_by_Q(focus_data)

# %%
unitprice_by_Q(focus_data)

# %%
quantity_by_Q(focus_data)
