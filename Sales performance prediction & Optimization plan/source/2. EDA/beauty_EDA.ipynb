# %% [markdown]
# # 상품군 : 이미용

# %%
import pandas as pd 
import numpy as np 
import os 

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

# %%
from timeseries_graph_functions import *  # 시각화용 함수 만든것 불러오기

# %%
# from timeseries_graph_functions import sales_by_yoill

# %%
pd.set_option('display.float_format', '{:.2f}'.format)    #과학적 표기법 안쓸래 
mpl.rcParams['axes.unicode_minus'] = False               # 마이너스 표기 오류 방지

# %%
# 한글 폰트 깨짐 방지 
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()   
rc('font', family=font_name)
# plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
base_dir = "C:\\programming\\bigcontest_2020\\champion_league\\preprocess\\saejin"
excel_file = "원데이터 전처리.xlsx"

excel_dir = os.path.join(base_dir,excel_file)

# %%
raw_data = pd.read_excel(excel_dir, 
                             sheet_name = "Sheet1",
                             header = 0)

# %%
raw_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드             상품명  \
# 0               1 2019-01-01 06:00:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 1               2 2019-01-01 06:00:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 2               3 2019-01-01 06:20:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 3               4 2019-01-01 06:20:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 4               5 2019-01-01 06:40:00  20.00  100346  201072   테이트 남성 셀린니트3종
# ...           ...                 ...    ...     ...     ...             ...
# 35370       38296 2019-12-31 23:20:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
# 35371       38297 2019-12-31 23:40:00  20.00  100448  201383  무이자쿠첸압력밥솥 10인용
# 35372       38298 2019-12-31 23:40:00  20.00  100448  201390  일시불쿠첸압력밥솥 10인용
# 35373       38299 2019-12-31 23:40:00  20.00  100448  201384   무이자쿠첸압력밥솥 6인용
# 35374       38300 2019-12-31 23:40:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가       취급액        날짜  ...   월   일   요일  분기 365일  계절  방송시간  \
# 0      의류   39900   2099000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 1      의류   39900   4371000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 2      의류   39900   3262000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 3      의류   39900   6955000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 4      의류   39900   6672000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# ...    ..     ...       ...       ...  ...  ..  ..  ...  ..  ...  ..   ...
# 35370  주방  148000   1664000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35371  주방  178000   9149000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35372  주방  168000  15282000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35373  주방  158000   2328000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35374  주방  148000  10157000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
#
#        매진여부  취급액boxcox  최소판매수량
# 0         0     109.82      53
# 1         0     130.05     110
# 2         0     121.58      82
# 3         0     144.68     174
# 4         0     143.31     167
# ...     ...        ...     ...
# 35370     0     104.07      11
# 35371     0     154.06      51
# 35372     0     173.20      91
# 35373     0     112.48      15
# 35374     0     157.78      69
#
# [35375 rows x 21 columns]

# %% [markdown]
# # 상품군 : 이미용

# %%
beauty_raw = raw_data[raw_data['상품군'] == '이미용']

# %%
focus_data = beauty_raw

# %%
focus_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1305 entries, 35 to 35264
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1305 non-null   int64
#  1   방송일시        1305 non-null   datetime64[ns]
#  2   노출(분)       1305 non-null   float64
#  3   마더코드        1305 non-null   int64
#  4   상품코드        1305 non-null   int64
#  5   상품명         1305 non-null   object
#  6   상품군         1305 non-null   object
#  7   판매단가        1305 non-null   int64
#  8   취급액         1305 non-null   int64
#  9   날짜          1305 non-null   int64
#  10  시간          1305 non-null   object
#  11  월           1305 non-null   int64
#  12  일           1305 non-null   int64
#  13  요일          1305 non-null   object
#  14  분기          1305 non-null   object
#  15  365일        1305 non-null   int64
#  16  계절          1305 non-null   object
#  17  방송시간        1305 non-null   float64
#  18  매진여부        1305 non-null   int64
#  19  취급액boxcox   1305 non-null   float64
#  20  최소판매수량      1305 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(11), object(6)
# memory usage: 224.3+ KB

# %%
focus_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드  \
# 35             36 2019-01-01 17:00:00  20.00  100074  200197
# 36             37 2019-01-01 17:20:00  20.00  100074  200197
# 37             38 2019-01-01 17:40:00  20.00  100074  200197
# 174           181 2019-01-03 08:00:00  20.00  100774  202261
# 175           182 2019-01-03 08:20:00  20.00  100774  202261
# ...           ...                 ...    ...     ...     ...
# 35242       38163 2019-12-30 12:40:00  20.00  100262  200876
# 35243       38164 2019-12-30 13:00:00  20.00  100262  200876
# 35262       38184 2019-12-30 20:20:00  20.00  100074  200199
# 35263       38185 2019-12-30 20:40:00  20.00  100074  200199
# 35264       38186 2019-12-30 21:00:00  20.00  100074  200199
#
#                               상품명  상품군   판매단가        취급액        날짜  ...   월  \
# 35     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용  39800   42239000  20190101  ...   1
# 36     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용  39800   73494000  20190101  ...   1
# 37     비버리힐스폴로클럽 남성기초세트(2018FW골드)  이미용  39800  107103000  20190101  ...   1
# 174          엘렌실라 달팽이크림(콜라겐5+팩트3)  이미용  79000   13665000  20190103  ...   1
# 175          엘렌실라 달팽이크림(콜라겐5+팩트3)  이미용  79000   26788000  20190103  ...   1
# ...                           ...  ...    ...        ...       ...  ...  ..
# 35242                  더블모 어성초 샴푸  이미용  59800   30608000  20191230  ...  12
# 35243                  더블모 어성초 샴푸  이미용  59800   53553000  20191230  ...  12
# 35262    비버리힐스폴로클럽 남성기초세트(골드+콜라겐)  이미용  39800   51010000  20191230  ...  12
# 35263    비버리힐스폴로클럽 남성기초세트(골드+콜라겐)  이미용  39800   73150000  20191230  ...  12
# 35264    비버리힐스폴로클럽 남성기초세트(골드+콜라겐)  이미용  39800   85718000  20191230  ...  12
#
#         일   요일  분기 365일  계절  방송시간  매진여부  취급액boxcox  최소판매수량
# 35      1  화요일  Q1    1  겨울 20.00     0     218.25    1061
# 36      1  화요일  Q1    1  겨울 20.00     0     247.42    1847
# 37      1  화요일  Q1    1  겨울 20.00     0     269.41    2691
# 174     3  목요일  Q1    3  겨울 20.00     0     168.84     173
# 175     3  목요일  Q1    3  겨울 20.00     0     196.81     339
# ...    ..  ...  ..  ...  ..   ...   ...        ...     ...
# 35242  30  월요일  Q4  364  겨울 20.00     0     202.86     512
# 35243  30  월요일  Q4  364  겨울 20.00     0     230.31     896
# 35262  30  월요일  Q4  364  겨울 20.00     0     227.79    1282
# 35263  30  월요일  Q4  364  겨울 20.00     0     247.16    1838
# 35264  30  월요일  Q4  364  겨울 20.00     0     256.19    2154
#
# [1305 rows x 21 columns]

# %%
sales_by_month(focus_data)

# %%
sales_by_time(focus_data)

# %%
sales_by_yoill(focus_data)

# %%
sales_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 총합')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 평균')

# %%
soldout_by_season(focus_data)
# Out:
#     매진여부
# 계절
# 가을     1
# 겨울     0
# 봄      0
# 여름     0

# %%
unitprice_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 총액')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 평균')

# %%
quantity_by_season(focus_data)

# %%
sales_by_Q(focus_data)

# %%
unitprice_by_Q(focus_data)

# %%
quantity_by_Q(focus_data)
