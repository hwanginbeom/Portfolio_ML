# %%
import pandas as pd 
import numpy as np 
import os 

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

# %%
from timeseries_graph_functions import *  # 시각화용 함수 만든것 불러오기

# %%
pd.set_option('display.float_format', '{:.2f}'.format)    #과학적 표기법 안쓸래 
mpl.rcParams['axes.unicode_minus'] = False               # 마이너스 표기 오류 방지

# %%
# 한글 폰트 깨짐 방지 
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()   
rc('font', family=font_name)

# %%
base_dir = "C:\\programming\\bigcontest_2020\\champion_league\\eda\\double_graph"
excel_file = "data_double_graph.xlsx"

excel_dir = os.path.join(base_dir,excel_file)

# %%
raw_data = pd.read_excel(excel_dir, 
                        sheet_name = "Sheet1",
                         header = 0)

# %% [raw]
# raw_data.head()

# %%
product_group =['가구', '가전', '의류', '속옷', '건강기능', '농수축', '생활용품', '이미용', '잡화', '주방', '침구']

# %%
# for product in product_group:
#     focus_data = raw_data[raw_data['상품군'] == product]
#     sicheong_sales_by_time(focus_data, product)

# %%
# for product in product_group:
#     focus_data = raw_data[raw_data['상품군'] == product]
#     sicheong_sales_by_month(focus_data, product)

# %%
# for product in product_group:
#     focus_data = raw_data[raw_data['상품군'] == product]
#     sicheong_sales_by_yoill(focus_data, product)

# %%
# for product in product_group:
#     focus_data = raw_data[raw_data['상품군'] == product]
#     sicheong_sales_by_season(focus_data, product)

# %%
for product in product_group:
    focus_data = raw_data[raw_data['상품군'] == product]
    sicheong_sales_by_Q(focus_data, product)
