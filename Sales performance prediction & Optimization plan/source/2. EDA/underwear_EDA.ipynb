# %% [markdown]
# # 상품군 : 속옷

# %%
import pandas as pd 
import numpy as np 
import os 

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

# %%
from timeseries_graph_functions import *  # 시각화용 함수 만든것 불러오기

# %%
pd.set_option('display.float_format', '{:.2f}'.format)    #과학적 표기법 안쓸래 
mpl.rcParams['axes.unicode_minus'] = False               # 마이너스 표기 오류 방지

# %%
# 한글 폰트 깨짐 방지 
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()   
rc('font', family=font_name)
# plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
base_dir = "C:\\programming\\bigcontest_2020\\champion_league\\preprocess\\saejin"
excel_file = "원데이터 전처리.xlsx"

excel_dir = os.path.join(base_dir,excel_file)

# %%
raw_data = pd.read_excel(excel_dir, 
                             sheet_name = "Sheet1",
                             header = 0)

# %%
raw_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드             상품명  \
# 0               1 2019-01-01 06:00:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 1               2 2019-01-01 06:00:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 2               3 2019-01-01 06:20:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 3               4 2019-01-01 06:20:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 4               5 2019-01-01 06:40:00  20.00  100346  201072   테이트 남성 셀린니트3종
# ...           ...                 ...    ...     ...     ...             ...
# 35370       38296 2019-12-31 23:20:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
# 35371       38297 2019-12-31 23:40:00  20.00  100448  201383  무이자쿠첸압력밥솥 10인용
# 35372       38298 2019-12-31 23:40:00  20.00  100448  201390  일시불쿠첸압력밥솥 10인용
# 35373       38299 2019-12-31 23:40:00  20.00  100448  201384   무이자쿠첸압력밥솥 6인용
# 35374       38300 2019-12-31 23:40:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가       취급액        날짜  ...   월   일   요일  분기 365일  계절  방송시간  \
# 0      의류   39900   2099000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 1      의류   39900   4371000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 2      의류   39900   3262000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 3      의류   39900   6955000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 4      의류   39900   6672000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# ...    ..     ...       ...       ...  ...  ..  ..  ...  ..  ...  ..   ...
# 35370  주방  148000   1664000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35371  주방  178000   9149000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35372  주방  168000  15282000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35373  주방  158000   2328000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35374  주방  148000  10157000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
#
#        매진여부  취급액boxcox  최소판매수량
# 0         0     109.82      53
# 1         0     130.05     110
# 2         0     121.58      82
# 3         0     144.68     174
# 4         0     143.31     167
# ...     ...        ...     ...
# 35370     0     104.07      11
# 35371     0     154.06      51
# 35372     0     173.20      91
# 35373     0     112.48      15
# 35374     0     157.78      69
#
# [35375 rows x 21 columns]

# %% [markdown]
# # 상품군 : 속옷

# %%
underwear_raw = raw_data[raw_data['상품군'] == '속옷']

# %%
focus_data = underwear_raw

# %%
focus_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3910 entries, 6 to 35288
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3910 non-null   int64
#  1   방송일시        3910 non-null   datetime64[ns]
#  2   노출(분)       3910 non-null   float64
#  3   마더코드        3910 non-null   int64
#  4   상품코드        3910 non-null   int64
#  5   상품명         3910 non-null   object
#  6   상품군         3910 non-null   object
#  7   판매단가        3910 non-null   int64
#  8   취급액         3910 non-null   int64
#  9   날짜          3910 non-null   int64
#  10  시간          3910 non-null   object
#  11  월           3910 non-null   int64
#  12  일           3910 non-null   int64
#  13  요일          3910 non-null   object
#  14  분기          3910 non-null   object
#  15  365일        3910 non-null   int64
#  16  계절          3910 non-null   object
#  17  방송시간        3910 non-null   float64
#  18  매진여부        3910 non-null   int64
#  19  취급액boxcox   3910 non-null   float64
#  20  최소판매수량      3910 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(11), object(6)
# memory usage: 672.0+ KB

# %%
focus_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드  \
# 6               7 2019-01-01 07:00:00  20.00  100305  200974
# 7               8 2019-01-01 07:20:00  20.00  100305  200974
# 8               9 2019-01-01 07:40:00  20.00  100305  200974
# 18             19 2019-01-01 11:00:00  20.00  100664  201999
# 19             20 2019-01-01 11:20:00  20.00  100664  201999
# ...           ...                 ...    ...     ...     ...
# 35278       38200 2019-12-31 00:00:00  20.00  100610  201884
# 35279       38201 2019-12-31 00:00:00  20.00  100610  201906
# 35286       38208 2019-12-31 01:20:00  20.00  100439  201357
# 35287       38209 2019-12-31 01:40:00  17.17  100439  201357
# 35288       38210 2019-12-31 02:00:00  20.00  100439  201357
#
#                              상품명 상품군   판매단가       취급액        날짜  ...   월   일  \
# 6               오모떼 레이스 파운데이션 브라  속옷  59000   6819000  20190101  ...   1   1
# 7               오모떼 레이스 파운데이션 브라  속옷  59000  15689000  20190101  ...   1   1
# 8               오모떼 레이스 파운데이션 브라  속옷  59000  25370000  20190101  ...   1   1
# 18     크로커다일 The 편안한 코튼 브라팬티 4세트  속옷  69900  24531000  20190101  ...   1   1
# 19     크로커다일 The 편안한 코튼 브라팬티 4세트  속옷  69900  49829000  20190101  ...   1   1
# ...                          ...  ..    ...       ...       ...  ...  ..  ..
# 35278          푸마 시그니처 코튼 트렁크 9종  속옷  89000   4801000  20191231  ...  12  31
# 35279               푸마 코튼 언더탑 9종  속옷  89000   3357000  20191231  ...  12  31
# 35286       루시헨느 레이스 홀리데이 란쥬 패키지  속옷  89900   6540000  20191231  ...  12  31
# 35287       루시헨느 레이스 홀리데이 란쥬 패키지  속옷  89900  22453000  20191231  ...  12  31
# 35288       루시헨느 레이스 홀리데이 란쥬 패키지  속옷  89900  29452000  20191231  ...  12  31
#
#         요일  분기 365일  계절  방송시간  매진여부  취급액boxcox  최소판매수량
# 6      화요일  Q1    1  겨울 20.00     0     144.03     116
# 7      화요일  Q1    1  겨울 20.00     0     174.24     266
# 8      화요일  Q1    1  겨울 20.00     0     194.39     430
# 18     화요일  Q1    1  겨울 20.00     0     192.91     351
# 19     화요일  Q1    1  겨울 40.00     1     226.58     713
# ...    ...  ..  ...  ..   ...   ...        ...     ...
# 35278  화요일  Q4  365  겨울 20.00     0     132.89      54
# 35279  화요일  Q4  365  겨울 20.00     0     122.39      38
# 35286  화요일  Q4  365  겨울 20.00     0     142.66      73
# 35287  화요일  Q4  365  겨울 17.17     0     189.07     250
# 35288  화요일  Q4  365  겨울 20.00     0     201.10     328
#
# [3910 rows x 21 columns]

# %%
sales_by_month(focus_data)

# %%
sales_by_time(focus_data)

# %%
sales_by_yoill(focus_data)

# %%
sales_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 총합')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 평균')

# %%
soldout_by_season(focus_data)
# Out:
#     매진여부
# 계절
# 가을     0
# 겨울     1
# 봄      1
# 여름     2

# %%
unitprice_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 총액')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 평균')

# %%
quantity_by_season(focus_data)

# %%
sales_by_Q(focus_data)

# %%
unitprice_by_Q(focus_data)

# %%
quantity_by_Q(focus_data)
