# %% [markdown]
# # 상품군 : 생활용품

# %%
import pandas as pd 
import numpy as np 
import os 

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib import rc

# %%
from timeseries_graph_functions import *  # 시각화용 함수 만든것 불러오기

# %%
pd.set_option('display.float_format', '{:.2f}'.format)    #과학적 표기법 안쓸래 
mpl.rcParams['axes.unicode_minus'] = False               # 마이너스 표기 오류 방지

# %%
# 한글 폰트 깨짐 방지 
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()   
rc('font', family=font_name)
# plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
base_dir = "C:\\programming\\bigcontest_2020\\champion_league\\preprocess\\saejin"
excel_file = "원데이터 전처리.xlsx"

excel_dir = os.path.join(base_dir,excel_file)

# %%
raw_data = pd.read_excel(excel_dir, 
                             sheet_name = "Sheet1",
                             header = 0)

# %%
raw_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드             상품명  \
# 0               1 2019-01-01 06:00:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 1               2 2019-01-01 06:00:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 2               3 2019-01-01 06:20:00  20.00  100346  201072   테이트 남성 셀린니트3종
# 3               4 2019-01-01 06:20:00  20.00  100346  201079   테이트 여성 셀린니트3종
# 4               5 2019-01-01 06:40:00  20.00  100346  201072   테이트 남성 셀린니트3종
# ...           ...                 ...    ...     ...     ...             ...
# 35370       38296 2019-12-31 23:20:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
# 35371       38297 2019-12-31 23:40:00  20.00  100448  201383  무이자쿠첸압력밥솥 10인용
# 35372       38298 2019-12-31 23:40:00  20.00  100448  201390  일시불쿠첸압력밥솥 10인용
# 35373       38299 2019-12-31 23:40:00  20.00  100448  201384   무이자쿠첸압력밥솥 6인용
# 35374       38300 2019-12-31 23:40:00  20.00  100448  201391   일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가       취급액        날짜  ...   월   일   요일  분기 365일  계절  방송시간  \
# 0      의류   39900   2099000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 1      의류   39900   4371000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 2      의류   39900   3262000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 3      의류   39900   6955000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# 4      의류   39900   6672000  20190101  ...   1   1  화요일  Q1    1  겨울 20.00
# ...    ..     ...       ...       ...  ...  ..  ..  ...  ..  ...  ..   ...
# 35370  주방  148000   1664000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35371  주방  178000   9149000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35372  주방  168000  15282000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35373  주방  158000   2328000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
# 35374  주방  148000  10157000  20191231  ...  12  31  화요일  Q4  365  겨울 20.00
#
#        매진여부  취급액boxcox  최소판매수량
# 0         0     109.82      53
# 1         0     130.05     110
# 2         0     121.58      82
# 3         0     144.68     174
# 4         0     143.31     167
# ...     ...        ...     ...
# 35370     0     104.07      11
# 35371     0     154.06      51
# 35372     0     173.20      91
# 35373     0     112.48      15
# 35374     0     157.78      69
#
# [35375 rows x 21 columns]

# %% [markdown]
# # 상품군 : 생활용품

# %%
dailysupplies_raw = raw_data[raw_data['상품군'] == '생활용품']

# %%
focus_data = dailysupplies_raw

# %%
focus_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2769 entries, 67 to 35360
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2769 non-null   int64
#  1   방송일시        2769 non-null   datetime64[ns]
#  2   노출(분)       2769 non-null   float64
#  3   마더코드        2769 non-null   int64
#  4   상품코드        2769 non-null   int64
#  5   상품명         2769 non-null   object
#  6   상품군         2769 non-null   object
#  7   판매단가        2769 non-null   int64
#  8   취급액         2769 non-null   int64
#  9   날짜          2769 non-null   int64
#  10  시간          2769 non-null   object
#  11  월           2769 non-null   int64
#  12  일           2769 non-null   int64
#  13  요일          2769 non-null   object
#  14  분기          2769 non-null   object
#  15  365일        2769 non-null   int64
#  16  계절          2769 non-null   object
#  17  방송시간        2769 non-null   float64
#  18  매진여부        2769 non-null   int64
#  19  취급액boxcox   2769 non-null   float64
#  20  최소판매수량      2769 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(11), object(6)
# memory usage: 475.9+ KB

# %%
focus_data
# Out:
#        Unnamed: 0                방송일시  노출(분)    마더코드    상품코드  \
# 67             68 2019-01-02 06:00:00  20.00  100229  200800
# 68             69 2019-01-02 06:20:00  20.00  100229  200800
# 69             70 2019-01-02 06:40:00  20.00  100229  200800
# 224           231 2019-01-03 20:00:00  20.00  100501  201514
# 225           232 2019-01-03 20:20:00  20.00  100501  201514
# ...           ...                 ...    ...     ...     ...
# 35356       38279 2019-12-31 20:40:00  20.00  100501  201517
# 35357       38280 2019-12-31 21:00:00  20.00  100501  201516
# 35358       38281 2019-12-31 21:00:00  20.00  100501  201518
# 35359       38282 2019-12-31 21:00:00  20.00  100501  201515
# 35360       38283 2019-12-31 21:00:00  20.00  100501  201517
#
#                                  상품명   상품군    판매단가       취급액        날짜  ...  \
# 67                    벨라홈 논슬립 옷걸이 세트  생활용품   29800   9605000  20190102  ...
# 68                    벨라홈 논슬립 옷걸이 세트  생활용품   29800  11265000  20190102  ...
# 69                    벨라홈 논슬립 옷걸이 세트  생활용품   29800  14371000  20190102  ...
# 224                       노비타 스마트 비데  생활용품  189000  41183000  20190103  ...
# 225                       노비타 스마트 비데  생활용품  189000  83995000  20190103  ...
# ...                              ...   ...     ...       ...       ...  ...
# 35356  일시불 1+1 국내제조 노비타 뉴스파 비데  무료설치  생활용품  418000   6379000  20191231  ...
# 35357      무이자 국내제조 노비타 뉴스파 비데  무료설치  생활용품  239000  19504000  20191231  ...
# 35358       일시불 국내제조 노비타 뉴스파 비데 무료설치  생활용품  219000  61370000  20191231  ...
# 35359  무이자 1+1 국내제조 노비타 뉴스파 비데  무료설치  생활용품  458000   6781000  20191231  ...
# 35360  일시불 1+1 국내제조 노비타 뉴스파 비데  무료설치  생활용품  418000  15181000  20191231  ...
#
#         월   일   요일  분기 365일  계절  방송시간  매진여부  취급액boxcox  최소판매수량
# 67      1   2  수요일  Q1    2  겨울 20.00     0     155.78     322
# 68      1   2  수요일  Q1    2  겨울 20.00     0     161.56     378
# 69      1   2  수요일  Q1    2  겨울 20.00     0     170.79     482
# 224     1   3  목요일  Q1    3  겨울 20.00     0     217.00     218
# 225     1   3  목요일  Q1    3  겨울 20.00     0     255.01     444
# ...    ..  ..  ...  ..  ...  ..   ...   ...        ...     ...
# 35356  12  31  화요일  Q4  365  겨울 20.00     0     141.85      15
# 35357  12  31  화요일  Q4  365  겨울 20.00     0     183.10      82
# 35358  12  31  화요일  Q4  365  겨울 20.00     0     237.53     280
# 35359  12  31  화요일  Q4  365  겨울 20.00     0     143.85      15
# 35360  12  31  화요일  Q4  365  겨울 20.00     0     172.94      36
#
# [2769 rows x 21 columns]

# %%
sales_by_month(focus_data)

# %%
sales_by_time(focus_data)

# %%
sales_by_yoill(focus_data)

# %%
sales_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 총합')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절 별 취급액 평균')

# %%
soldout_by_season(focus_data)
# Out:
#     매진여부
# 계절
# 가을     0
# 겨울     0
# 봄      0
# 여름     4

# %%
unitprice_by_season(focus_data)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 총액')
# AxesSubplot(0.125,0.125;0.775x0.755)
# Text(0.5, 1.0, '계절별 판매단가 평균')

# %%
quantity_by_season(focus_data)

# %%
sales_by_Q(focus_data)

# %%
unitprice_by_Q(focus_data)

# %%
quantity_by_Q(focus_data)
